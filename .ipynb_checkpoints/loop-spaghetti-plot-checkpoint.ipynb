# %%
import matplotlib.pyplot as plt
%matplotlib inline
import numpy as np
# Out:
# syntax: invalid "import" statement
# while loading In[1], in expression starting on line 1

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
fig = plt.figure(figsize=(10,5))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11bb2bf90>)
# PyObject <matplotlib.axes._axes.Axes object at 0x11bec0350>

# %%
trial = 7
forecastFlux = readcsv("forecastFlux-$(dec(trial,3)).csv")
analysisFlux = readcsv("analysisFlux-$(dec(trial,3)).csv")
truthFlux = readcsv("truthFlux-$(dec(trial,3)).csv")
# Out:
# 10x1 Array{Float64,2}:
#  -1.43737e-10
#  -1.61285e-10
#  -1.81475e-10
#  -2.04707e-10
#  -2.31267e-10
#  -2.61402e-10
#  -2.95596e-10
#  -3.3433e-10
#  -3.77963e-10
#  -4.26498e-10

# %%
Nens = size(forecastFlux)[1]
for i=1:Nens
    println(forecastFlux[i,:]'')
end
# Out:
# [2.2699611e-9 9.75089075e-10 9.1988861e-10 8.791664200000001e-10 8.43637925e-10 8.078546524999998e-10 7.70532895e-10 7.307607025e-10 6.894497140000001e-10 6.473355435000001e-10]
# [3.5175700875000005e-9 1.5258065e-9 1.4515934000000002e-9 1.397727875e-9 1.3534315e-9 1.311235425e-9 1.2703418225e-9 1.2296055999999999e-9 1.1859454125e-9 1.1386566899999998e-9]
# [-2.9698166e-9 -1.34538205e-9 -1.3398618000000001e-9 -1.3505455e-9 -1.3683278249999999e-9 -1.3924061e-9 -1.4220528500000001e-9 -1.45434325e-9 -1.4917996500000003e-9 -1.5347370999999997e-9]
# [6.023547075e-9 2.717056575e-9 2.616889075e-9 2.5445629500000003e-9 2.4845010999999994e-9 2.4281285250000003e-9 2.373293525e-9 2.317744025e-9 2.2606531750000002e-9 2.200197725e-9]
# [-7.55903905e-9 -3.370630225e-9 -3.3090052749999993e-9 -3.2877557499999993e-9 -3.2833578e-9 -3.2917355750000003e-9 -3.309098675e-9 -3.3356214999999998e-9 -3.372856325e-9 -3.421740825e-9]
# ...

# %%
fig = plt.figure(figsize=(10,5))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
ax[:plot](1:length(truthFlux),truthFlux)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11bafe110>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11ca79250>

# %%
fig = plt.figure(figsize=(10,5))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
ax[:plot](1:length(truthFlux),truthFlux,"b")
for i=1:Nens
    println(size(forecastFlux[i,:]))
    ax[:plot](1:length(forecastFlux[i,:]),forecastFlux[i,:]',"r")
end
# Out:
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# (1,10)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11c8ba310>)

# %%
length(100:10:1000)
# Out:
# 91
