# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
println("test plot")
x = linspace(0,2*pi,1000); y = sin(3*x + 4*cos(2*x));
plot(x, y, color="red", linewidth=2.0, linestyle="--")
title("A sinusoidally modulated sinusoid")
# Out:
# test plot
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ed43ed0>)
# PyObject <matplotlib.text.Text object at 0x122f2bf50>

# %%
for bottom in 260:10:290
    for top in 310:10:370
        f = open("download/BCTest-$(bottom)-$(top)/Phiavg.csv")
        post = readcsv(f)
        close(f)
        phi = post[1,:]'
        times = 1:length(phi)
        plot(times,phi, color="red", linewidth=2.0, linestyle="--")
        title("BCTest-$(bottom)-$(top)")
    end
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x122b0ae10>)

# %%
# Out:
# 2-element Array{String,1}:
#  "one "
#  "1"

# %%
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x110b894d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x1206250d0>
