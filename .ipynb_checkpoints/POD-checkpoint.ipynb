# %%
# load up the timeseries from the model
# using only temperature
include("foamLia/foamLia.jl")
using foamLia

# %%
baseCase = OpenFoam("/Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase");
initCase(baseCase,"foamLia/test/juliabase/");
faces,cells = readMesh(baseCase);
points,indices = reshapeMesh(baseCase);
# Out:
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultControlDict at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:83
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:106
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:107
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:111
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:114
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:124
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:133
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:136
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSchemes at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:139
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:147
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:149
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:151
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:157
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:161
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:167
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:172
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:181
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:182
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultFvSolution at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:183
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultSetFieldsDict at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:191
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultRASProperties at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:205
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultTransportProperties at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:213
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultG at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:198
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:263
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:302
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:303
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:305
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:307
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:314
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:321
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultT at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:328
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:340
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:345
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:346
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:349
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:352
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:355
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:358
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultPhi at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:361
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:369
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:374
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:375
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:377
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:379
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:382
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:385
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultU at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:388
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:396
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:401
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:402
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:404
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:406
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:409
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:412
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultP at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:415
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultMeshParam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:425
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# WARNING: (OrderedDict{K,V})(::Type{K},::Type{V}) is deprecated, use (OrderedDict{K,V})() instead.
#  in OrderedDict at deprecated.jl:26
#  in create_defaultMesh at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:435
#  in OpenFoam at /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/foamLia.jl:450
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /Users/andyreagan/.julia/v0.3/IJulia/src/execute_request.jl:157
#  in eventloop at /Users/andyreagan/.julia/v0.3/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:340
# /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/system exists
# /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh exists
# /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0 exists
# copying over base case
# copying foamLia/test/juliabase//Allrun to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/Allrun
# copying foamLia/test/juliabase//0/alphat to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0/alphat
# copying foamLia/test/juliabase//0/p to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0/p
# copying foamLia/test/juliabase//0/p_rgh to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0/p_rgh
# copying foamLia/test/juliabase//0/T to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0/T
# copying foamLia/test/juliabase//0/U to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/0/U
# copying foamLia/test/juliabase//constant/polyMesh/boundary to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh/boundary
# copying foamLia/test/juliabase//constant/polyMesh/faces to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh/faces
# copying foamLia/test/juliabase//constant/polyMesh/neighbour to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh/neighbour
# copying foamLia/test/juliabase//constant/polyMesh/owner to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh/owner
# copying foamLia/test/juliabase//constant/polyMesh/points to /Users/andyreagan/work/2014/2014-11foamLab-julia/foamLia/test/testPlotCase/constant/polyMesh/points
# writing out controlDict
# writing out fvSchemes
# writing out fvSolution
# writing out setFieldsDict
# writing out RASProperties
# writing out transportProperties
# writing out turbulenceProperties
# writing out g
# writing out T
# writing out phi
# writing out U
# writing out p

# %%
# let's go get the foward four points of each cell
# only get the yz coordinates
cellPoints = zeros(size(baseCase.fullMesh["cellFaces"])[2],4,3)
for cellID in 1:size(baseCase.fullMesh["cellFaces"])[2]
    faces = baseCase.fullMesh["cellFaces"][:,cellID]
    # println(faces)
    pointList = Int[]
    for faceID in 1:6
        face = faces[faceID]
        pointIDs = baseCase.fullMesh["faces"][:,face]
        # println(pointIDs)
        for pointID in 1:4
            point = pointIDs[pointID]
            if point ∉ pointList
                push!(pointList,point)
            end
        end
    end
    # println(pointList)
    # print(size(pointList))
    j = 0
    for (i,point) in enumerate(pointList)
        # println(i)
        # println(point)
        # println(baseCase.fullMesh["points"][:,point])
        pointXYZ = baseCase.fullMesh["points"][:,point]
        if pointXYZ[1] > 0
            j += 1
            cellPoints[cellID,j,:] = pointXYZ
        end
    end
end

# %%
T = readVar(baseCase,"8815","T")
U = readVar(baseCase,"8815","U")
Umag = sqrt(sum(U[2:3,:].^2,1))
Tminmax = (minimum(T)+10,maximum(T)-10)
Tdiff = Tminmax[2]-Tminmax[1]
Uminmax = (minimum(Umag),maximum(Umag))
Udiff = Uminmax[2]-Uminmax[1]
Tsquashed = (squeeze(T,1)-Tminmax[1])/Tdiff
Usquashed = (Umag-Uminmax[1])/Udiff
# Out:
# 1x40000 Array{Float64,2}:
#  0.204639  0.415666  0.508033  0.530428  …  0.168514  0.110889  0.0419161

# %%
# all of the function that are necessary for plotting
using PyPlot
using PyCall
@pyimport matplotlib as mpl
patches = mpl.pymember("patches")

RdYlBu = readcsv("/Users/andyreagan/work/2014/2014-11foamLab-julia/RdYlBu.csv");
function cmapper(cmap,val)
    squeeze(cmap[min(max(ceil(val*255),1),255),:],1)
end

lookup_table = zeros(40000,4)
lookup_table[1:19999,:] = repmat([1,2,4,3]',19999,1)
# bottom right
lookup_table[20000:30000,:] = repmat([1,2,3,4]',10001,1)
# flip every 40th
lookup_table[20000:40:29999,:] = repmat([1,2,4,3]',250,1)
lookup_table[30001:40000,:] = repmat([1,2,4,3]',10000,1)
lookup_table[40,:] = [1,2,3,4]'
lookup_table[39961:40000,:] = repmat([1,2,3,4]',40,1)
lookup_table[29961:29999,:] = repmat([1,2,4,3]',39,1)
function cell_point_order(cellID)
    # a lookup for how to reorder the point
    return squeeze(lookup_table[cellID,:],1)
end
# Out:
# INFO: Loading help data...
# cell_point_order (generic function with 1 method)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
offset = zeros(4,2)
offset[:,1] = .04
for cellID in 1:1000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,Tsquashed[cellID]),rasterized=true)
    ax[:add_patch](p)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:]+offset,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,Usquashed[cellID]),rasterized=true)
    ax[:add_patch](p)
end
ax[:quiver](baseCase.fullMesh["cellCenters"][2,1:5:1000]+0.08,baseCase.fullMesh["cellCenters"][3,1:5:1000],U[2,1:5:1000],U[3,1:5:1000],width=0.0007)
for cellID in 10000:11000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,Tsquashed[cellID]),rasterized=true)
    ax[:add_patch](p)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:]+offset,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,Usquashed[cellID]),rasterized=true)
    ax[:add_patch](p)
end
ax[:quiver](baseCase.fullMesh["cellCenters"][2,10000:5:11000]+0.08,baseCase.fullMesh["cellCenters"][3,10000:5:11000],U[2,10000:5:11000],U[3,10000:5:11000],width=0.0007)
# ax[:set_xlim]([-1,1]*0.5)
# ax[:set_ylim]([-1,1]*0.5)
ax[:set_xlim]([-.39,-.19])
ax[:set_ylim]([-0.10,.05])
plt.savefig("DMD-testing-003.png")
# Out:
# BoundsError()
# while loading In[60], in expression starting on line 13
#
#  in getindex at /Users/andyreagan/.julia/v0.3/PyCall/src/PyCall.jl:246
#  in pysequence_query at /Users/andyreagan/.julia/v0.3/PyCall/src/conversions.jl:776
#  in pytype_query at /Users/andyreagan/.julia/v0.3/PyCall/src/conversions.jl:792
#  in convert at /Users/andyreagan/.julia/v0.3/PyCall/src/conversions.jl:842
#  in pycall at /Users/andyreagan/.julia/v0.3/PyCall/src/PyCall.jl:403
#  in fn at /Users/andyreagan/.julia/v0.3/PyCall/src/conversions.jl:188
#  in close_queued_figs at /Users/andyreagan/.julia/v0.3/PyPlot/src/PyPlot.jl:296

# %%
println(size(squeeze(T,1)))
# Out:
# (40000,)

# %%
times = 100:10:1000
println(size(times))
D = zeros(size(squeeze(T,1))[1],size(times)[1])
for time=1:size(times)[1]
    t = times[time]
    T = readVar(baseCase,stringG(t),"T")
    D[:,time] = squeeze(T,1)
end
# Out:
# (91,)

# %%
size(D)
# Out:
# (40000,91)

# %%
D[1:10,1:10]
# Out:
# 10x10 Array{Float64,2}:
#  314.505  316.867  318.601  317.656  …  311.71   308.701  287.624  290.253
#  310.868  314.114  315.002  313.268     307.66   304.873  291.63   296.136
#  306.496  311.936  311.852  309.509     303.498  301.411  295.109  300.46
#  302.864  310.486  309.8    307.376     300.405  299.906  297.299  302.903
#  301.746  309.636  308.646  306.391     298.544  299.586  298.377  304.122
#  301.751  309.184  308.113  305.999  …  297.807  299.565  298.793  304.713
#  301.904  308.801  308.045  305.875     297.74   299.58   298.905  305.004
#  302.052  308.206  308.319  305.866     297.965  299.616  298.907  305.143
#  302.186  307.351  308.666  305.909     298.324  299.683  298.878  305.195
#  302.306  306.345  308.881  305.975     298.747  299.77   298.846  305.193

# %%
println(D[1,:])
# Out:
# [314.505 316.867 318.601 317.656 315.832 313.888 311.71 308.701 287.624 290.253 291.505 293.583 311.432 316.228 315.092 314.852 310.621 311.962 313.367 289.25 289.312 289.604 291.076 291.333 292.219 292.195 295.713 291.134 288.533 289.949 289.873 291.397 290.816 290.206 310.254 317.768 315.7 314.464 314.96 315.144 315.927 314.301 314.64 317.018 316.838 314.772 314.159 315.85 313.855 316.019 316.32 315.79 316.755 315.326 315.365 314.393 312.055 312.198 313.352 316.476 315.822 316.263 317.735 316.214 314.633 312.669 299.006 290.052 291.558 293.725 293.399 292.688 295.035 292.181 292.187 292.629 290.556 291.939 292.74 293.774 292.943 293.379 292.28 291.461 290.419 292.128 291.947 292.941 292.516 292.679 292.499]

# %%
F = svdfact(D)
# Out:
# SVD{Float64,Float64}(40000x91 Array{Float64,2}:
#  -0.00500797   0.0106898     0.0520818    …  0.00633409    0.0211585
#  -0.00500752   0.00828042    0.0343183       0.013077      0.0194387
#  -0.00500359   0.00598277    0.0205722       0.0151336     0.0148957
#  -0.00500121   0.00439882    0.0119501       0.0135167     0.0101198
#  -0.00500017   0.0036814     0.00694263      0.0101268     0.00598868
#  -0.00499962   0.00340916    0.00408248   …  0.007033      0.00208204
#  -0.00499911   0.00327533    0.00240282      0.00489051   -0.00129707
#  -0.00499863   0.00318278    0.00139253      0.00358997   -0.00381062
#  -0.00499827   0.00308861    0.00080284      0.00303247   -0.00539705
#  -0.00499807   0.00298789    0.00048784      0.0030153    -0.00598669
#  -0.00499787   0.002863      0.000324547  …  0.0030677    -0.00597074
#  -0.0049976    0.00271345    0.000238639     0.00296815   -0.00561663
#  -0.00499729   0.00255502    0.000198996     0.00272069   -0.00499818
#   ⋮                                       ⋱                ⋮
#  -0.0049889   -0.00561162    0.000218145     0.0026296    -0.000897424
#  -0.0049874   -0.00532118    0.000169017     0.00285126   -0.000794019
#  -0.00498536  -0.00496371    0.000105902  …  0.00271216   -0.00135641
#  -0.00498275  -0.0045548     3.08856e-5      0.00200449   -0.00265475
#  -0.00497963  -0.00410153   -2.42067e-5      0.000891599  -0.00383462
#  -0.0049759   -0.00359835   -9.99064e-6      0.000387126  -0.00402554
#  -0.00497116  -0.00306425    0.000113088     0.00123627   -0.00360083
#  -0.00496439  -0.00258399    0.000326432  …  0.00240679   -0.00388922
#  -0.00495241  -0.00213227    0.000453579     0.00424488   -0.00612758
#  -0.00492858  -0.00138633    0.000341879     0.00680437   -0.0074967
#  -0.00488452  -0.000146196   8.89967e-5      0.00498462   -0.00651571
#  -0.00481653   0.00086898   -1.7977e-5       3.58551e-5   -0.00664939 ,[578481.0,2220.47,2003.83,1742.2,960.595,817.212,745.466,498.656,450.105,411.033  …  124.376,121.714,118.845,114.163,110.28,109.681,106.692,102.995,98.2204,94.9221],91x91 Array{Float64,2}:
#  -0.104066    -0.104097     -0.104127    …  -0.105242     -0.105245
#   0.30609      0.335793      0.330558        0.0705846     0.119692
#  -0.0267423   -0.00679832    0.0329045      -0.0707228    -0.0604679
#   0.0379351    0.0148759    -0.0878805       0.0239969     0.0377049
#  -0.31663     -0.329897     -0.228843        0.0918746    -0.0171156
#  -0.106533    -0.0523036     0.10361     …  -0.171293     -0.167567
#   0.178015     0.139799     -0.0769757       0.114248      0.189957
#   0.0260063   -0.0152714    -0.138879        0.0507935     0.147942
#  -0.0856979   -0.139182     -0.124135        0.075562      0.00316234
#   0.0539981    0.000372518   0.0319585       0.0890293    -0.104748
#  -0.0117279    0.0172859     0.0427989   …  -0.0439666    -0.054408
#   0.0444913    0.172244      0.199126       -0.136923     -0.142769
#  -0.0991052   -0.152928     -0.0875888      -0.0557867     0.0502477
#   ⋮                                      ⋱                 ⋮
#  -0.110725     0.0387169    -0.00191309     -0.00691624   -0.032707
#  -0.0412693    0.0803996    -0.0239085   …   0.0103914     0.0343548
#  -0.0197634    0.0188167    -0.0712474       0.0687511     0.00609538
#   0.00971928   0.00327034    0.00612973     -0.0378219     0.0256765
#   0.022945    -0.0130998    -0.0213482      -0.0679547     0.0623472
#  -0.0279159   -0.00734124    0.0421034       0.0225172    -0.0541168
#  -0.00528486   0.00917121   -0.00522435  …  -0.00863781   -0.0204391
#  -0.00229448  -0.036981      0.0123093      -0.0245511     0.0497985
#   0.0189621    0.00673411   -0.0044556       0.038612     -0.00902454
#   0.00246587  -0.0131578     0.0142137      -0.0278844     0.0149195
#  -0.0227422   -0.00833344    0.0018794       0.000282611  -0.063666
#   0.0176016   -0.0185335     0.0219588   …  -0.057277      0.0129302 )

# %%
U = F[:U];
S = F[:S];
Vt = F[:Vt];
println(S)
# Out:
# [578480.5537630214,2220.47376555599,2003.8336344110737,1742.197053163126,960.594670113937,817.2123048094043,745.4660540514823,498.655723622284,450.10489851221536,411.0332776175695,400.6788242932252,372.46619461329476,362.0790083464927,345.92574982599507,335.6802306622617,323.7470954075689,319.2267144345644,308.61464723412143,303.84362061289227,297.92999207736415,291.6630035434276,288.64136655686457,285.79510795680505,278.8247508454173,277.01369777514475,271.829005949451,266.6973997637961,260.82871944154425,255.81450959955345,255.3247796020482,248.7239210003435,246.02185043324707,241.45741078136746,240.08808606517175,238.58548386842304,234.40017818698715,229.2088993445654,226.63373026339198,222.35138885149888,221.9037268520474,216.76961301842675,213.69320742045804,211.93960345287115,208.19297475556291,204.78229097779695,203.57134505255968,203.0567448135004,198.4067108272062,196.48754348357636,192.90858461282252,191.57410362363677,188.7834737389531,186.645059115114,184.4380988081771,182.20563188903904,181.32408078186927,179.6240372190076,177.94263432526643,176.618662897988,175.04060651584132,170.8275293138767,169.209769804658,165.49009533453284,163.85591829526,160.75097361418887,159.67702071654088,156.96392969257943,153.96362486914302,152.43255038866647,151.29223321086482,148.66043185369634,147.25755461874815,144.75693479996298,142.6166273688712,137.45289895839278,135.2991772080986,134.42982152105682,131.31478882483822,128.55675320866953,128.01034793321836,125.15901744750104,124.37561501327268,121.71380506045574,118.84545714482954,114.16318952945645,110.27976939916412,109.68060377931613,106.69246763545242,102.99500902824978,98.22041861606102,94.92209638819166]

# %%
fig = PyPlot.matplotlib[:pyplot][:figure](figsize=(5,5))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
ax[:plot](log10(S[1:10]))
# plt.plot(log10(S[1:10]))
ax[:set_ylabel]("log10(S)")
ax[:set_xlabel]("mode")
# plt.ylabel("log10(S)")
# plt.xlabel("mode")
# plt.savefig("/Users/andyreagan/work/2014/2014-11foamLab-julia/POD-spectrum.pdf")
PyPlot.matplotlib[:pyplot][:savefig]("/Users/andyreagan/work/2014/2014-11foamLab-julia/POD-spectrum-002.pdf")
# open(file -> writemime(file, "image/png", plt.gcf()), "test.png", "w")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x13a5dc050>)

# %%
U[1:10,1:10]
# Out:
# 10x10 Array{Float64,2}:
#  -0.00500797  0.0106898   0.0520818   …  -0.0150351   -0.0127913
#  -0.00500752  0.00828042  0.0343183      -0.00793424  -0.0102161
#  -0.00500359  0.00598277  0.0205722      -0.00458709  -0.00647254
#  -0.00500121  0.00439882  0.0119501      -0.00409043  -0.00341335
#  -0.00500017  0.0036814   0.00694263     -0.00451977  -0.00129689
#  -0.00499962  0.00340916  0.00408248  …  -0.00475663  -0.00020078
#  -0.00499911  0.00327533  0.00240282     -0.00467198   3.15878e-5
#  -0.00499863  0.00318278  0.00139253     -0.00439308  -0.000231274
#  -0.00499827  0.00308861  0.00080284     -0.00400532  -0.00067399
#  -0.00499807  0.00298789  0.00048784     -0.00351776  -0.00132313

# %%
Umax = maximum(U)
# Out:
# 0.05208181873018024

# %%
Umin = minimum(U)
# Out:
# -0.05488501455383986

# %%
Urange = Umax-Umin
# Out:
# 0.1069668332840201

# %%
fig = PyPlot.matplotlib[:pyplot][:figure](figsize=(10,10))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
for cellID in 1:40000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,1]-Umin)/Urange),rasterized=true)
    ax[:add_patch](p)
end
# ax[:set_xlim]([-.39,-.19])
# ax[:set_ylim]([-0.10,.05])
ax[:set_xlim]([-1,1]*0.38)
ax[:set_ylim]([-1,1]*0.38)
PyPlot.matplotlib[:pyplot][:savefig]("/Users/andyreagan/work/2014/2014-11foamLab-julia/POD-mode01.pdf")

# %%
mode = 2
fig = PyPlot.matplotlib[:pyplot][:figure](figsize=(10,10))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
for cellID in 1:40000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,mode]-Umin)/Urange),rasterized=true)
    ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,2]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset*2,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,91]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
end
# ax[:set_xlim]([-.39,-.19])
# ax[:set_ylim]([-0.10,.05])
ax[:set_xlim]([-1,1]*0.38)
ax[:set_ylim]([-1,1]*0.38)
PyPlot.matplotlib[:pyplot][:savefig]("/Users/andyreagan/work/2014/2014-11foamLab-julia/POD-mode$(dec(mode,2)).pdf")

# %%
fig = plt.figure(figsize=(10,10))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
for cellID in 1:40000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,3]-Umin)/Urange),rasterized=true)
    ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,2]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset*2,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,91]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
end
# ax[:set_xlim]([-.39,-.19])
# ax[:set_ylim]([-0.10,.05])
ax[:set_xlim]([-1,1]*0.38)
ax[:set_ylim]([-1,1]*0.38)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x12b90a9d0>)
# (-0.4,0.4)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig[:add_axes]([0.2,0.2,0.7,0.7])
for cellID in 1:40000
    pts = cellPoints[cellID,:,2:3]
    # println(pts)
    p = patches[:Polygon](squeeze(pts,1)[cell_point_order(cellID),:],closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,4]-Umin)/Urange),rasterized=true)
    ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,2]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
    # p = patches[:Polygon](squeeze(pts,1)[[1,2,4,3],:]+offset*2,closed=true,edgecolor="none",facecolor=cmapper(RdYlBu,(U[cellID,91]-Umin)/Urange),rasterized=true)
    # ax[:add_patch](p)
end
# ax[:set_xlim]([-.39,-.19])
# ax[:set_ylim]([-0.10,.05])
ax[:set_xlim]([-1,1]*0.38)
ax[:set_ylim]([-1,1]*0.38)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x13b9b9ed0>)
# (-0.38,0.38)

# %%
40*15
# Out:
# 600
