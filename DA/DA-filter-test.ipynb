# %%
include("testscript.jl")
# Out:
# yay julia
# library loaded
# [-7.7530111424121095,-7.271620036919892,26.763504343033652]
# [-7.816204899858597,-7.3073903421353075,26.837419979090768]
# [7.68076278684891,8.643811623502868,24.61817564347069]
# [-18.879491095315146,-7.8014751399893125,40.420415492127226]
# [-9.429766895784237,-9.343728406813504,28.28021602317535]
# [-9.436558307972879,-9.315445024724301,28.179787764905566]
# [-9.456192048781796,-9.378883842770431,28.22155929492902]
# [-9.474140704990106,-9.274587755344704,28.18418326248607]

# %%
using Gadfly

# %%
plot(x=0:window:runtime,y=truth[1,:],Guide.XLabel("Time"), Guide.YLabel("Truth"), Geom.point, Geom.line, )
# plot(x=0:window:runtime,y=observations[1,:])
# Out:
# Plot(...)

# %%
plot(x=0:window:runtime,y=observations[1,:],Guide.XLabel("Time"), Guide.YLabel("Truth"), Geom.point, Geom.line, )
# Out:
# Plot(...)

# %%
plot(x=0:window:runtime,y=forecast[1,:],Guide.XLabel("Time"), Guide.YLabel("Truth"), Geom.point, Geom.line)
# Out:
# Plot(...)
